# %%
def search_binary(sortarray, target):
    left = 0
    right = len(sortarray) - 1
    while left <= right:
        midpoint = left + (right - left) // 2
        current = sortarray[midpoint]
        if current == target:
            return midpoint
        else:
            if target < current:
                right = midpoint - 1
            else:
                left = midpoint + 1
    return None

# %%
#Defines the number of values
target = 3
sortarray = [0, 1, 2, 3, 4, 5]

result = search_binary(sortarray, target)

if result is not None:
    print('Value {} found at position {} using binary search'.format(target, result+1))
else:
    print('Not found')
# Out:
# Value 3 found at position 4 using binary search
