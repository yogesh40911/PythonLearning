# %%
from random import randint

val = ['Rock', 'Paper', 'Scissors? ']

comp = val[randint(0,2)]

player=False

while player==False:
  player = input('Rock,Paper,Scissors?')
  if player==comp:
    print('Tie!')
  elif player=='Rock':
    if comp=='Paper':
      print('You loose!', comp,"covers",player)
    else:
      print('You win!',player,"smashes",comp)
  elif player=='Paper':
    if comp=='Scissors':
      print('You loose',comp,"cut",player)
    else:
      print('You win!',player,'cut',comp)
  elif player=='Scissors':
    if comp=='Rock':
      print('You lose..',comp,'smashes',player)
    else:
      print('You win!',player,'cut',comp)
  elif player=='Finish':
    print('Finish the game..')
    break
  else:
    print('Thats not a valid play. check your spelling')
  
  player=False
  comp=val[randint(0,2)]
# Out:
# Rock,Paper,Scissors?Finish
# Finish the game..
